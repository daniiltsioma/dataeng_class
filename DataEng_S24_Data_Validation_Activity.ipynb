# %%
# Daniil Tsioma
import pandas

df = pandas.read_csv("/content/Hwy26Crashes2019_S23.csv")
df
# Out:
#       Crash ID  Record Type  Vehicle ID  Participant ID  \
# 0      1809119            1         NaN             NaN
# 1      1809119            2   3409578.0             NaN
# 2      1809119            3   3409578.0       3887884.0
# 3      1809119            2   3409579.0             NaN
# 4      1809119            3   3409579.0       3887885.0
# ...        ...          ...         ...             ...
# 2734   1860771            1         NaN             NaN
# 2735   1860771            2   3503992.0             NaN
# 2736   1860771            3   3503992.0       3991482.0
# 2737   1860771            2   3503993.0             NaN
# 2738   1860771            3   3503993.0       3991483.0
#
#       Participant Display Seq#  Vehicle Coded Seq#  Participant Vehicle Seq#  \
# 0                          NaN                 NaN                       NaN
# 1                          NaN                 1.0                       NaN
# 2                          1.0                 1.0                       1.0
# 3                          NaN                 2.0                       NaN
# 4                          2.0                 2.0                       1.0
# ...                        ...                 ...                       ...
# 2734                       NaN                 NaN                       NaN
# 2735                       NaN                 1.0                       NaN
# 2736                       1.0                 1.0                       1.0
# 2737                       NaN                 2.0                       NaN
# 2738                       2.0                 2.0                       1.0
#
#       Serial #  Crash Month  Crash Day  ...  Participant Cause 2 Code  \
# 0      99992.0          3.0       14.0  ...                       NaN
# 1          NaN          NaN        NaN  ...                       NaN
# 2          NaN          NaN        NaN  ...                       NaN
# 3          NaN          NaN        NaN  ...                       NaN
# 4          NaN          NaN        NaN  ...                       NaN
# ...        ...          ...        ...  ...                       ...
# 2734    1465.0          5.0        6.0  ...                       NaN
# 2735       NaN          NaN        NaN  ...                       NaN
# 2736       NaN          NaN        NaN  ...                       NaN
# 2737       NaN          NaN        NaN  ...                       NaN
# 2738       NaN          NaN        NaN  ...                       NaN
#
#       Participant Cause 3 Code  Participant Event 1 Code  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          0.0                       9.0
# 3                          NaN                       NaN
# 4                          NaN                       9.0
# ...                        ...                       ...
# 2734                       NaN                       NaN
# 2735                       NaN                       NaN
# 2736                       NaN                       NaN
# 2737                       NaN                       NaN
# 2738                       NaN                       NaN
#
#       Participant Event 2 Code  Participant Event 3 Code  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          0.0                       0.0
# 3                          NaN                       NaN
# 4                          9.0                       0.0
# ...                        ...                       ...
# 2734                       NaN                       NaN
# 2735                       NaN                       NaN
# 2736                       NaN                       0.0
# 2737                       NaN                       NaN
# 2738                       NaN                       0.0
#
#       BAC Test Results Code  Alcohol Use Reported  Drug Use Reported  \
# 0                       NaN                   NaN                NaN
# 1                       NaN                   NaN                NaN
# 2                       NaN                   NaN                NaN
# 3                       NaN                   NaN                NaN
# 4                       NaN                   NaN                NaN
# ...                     ...                   ...                ...
# 2734                    NaN                   NaN                NaN
# 2735                    NaN                   NaN                NaN
# 2736                    NaN                   NaN                NaN
# 2737                    NaN                   NaN                NaN
# 2738                    NaN                   NaN                NaN
#
#       Participant Marijuana Use Reported  Participant Striker Flag
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
# ...                                  ...                       ...
# 2734                                 NaN                       NaN
# 2735                                 NaN                       NaN
# 2736                                 NaN                       NaN
# 2737                                 NaN                       NaN
# 2738                                 NaN                       NaN
#
# [2739 rows x 157 columns]

# %%
crashes = df.loc[df['Record Type'] == 1]
crashes
# Out:
#       Crash ID  Record Type  Vehicle ID  Participant ID  \
# 0      1809119            1         NaN             NaN
# 5      1809229            1         NaN             NaN
# 9      1809637            1         NaN             NaN
# 12     1810874            1         NaN             NaN
# 16     1812266            1         NaN             NaN
# ...        ...          ...         ...             ...
# 2716   1860371            1         NaN             NaN
# 2719   1860417            1         NaN             NaN
# 2724   1860427            1         NaN             NaN
# 2729   1860453            1         NaN             NaN
# 2734   1860771            1         NaN             NaN
#
#       Participant Display Seq#  Vehicle Coded Seq#  Participant Vehicle Seq#  \
# 0                          NaN                 NaN                       NaN
# 5                          NaN                 NaN                       NaN
# 9                          NaN                 NaN                       NaN
# 12                         NaN                 NaN                       NaN
# 16                         NaN                 NaN                       NaN
# ...                        ...                 ...                       ...
# 2716                       NaN                 NaN                       NaN
# 2719                       NaN                 NaN                       NaN
# 2724                       NaN                 NaN                       NaN
# 2729                       NaN                 NaN                       NaN
# 2734                       NaN                 NaN                       NaN
#
#       Serial #  Crash Month  Crash Day  ...  Participant Cause 2 Code  \
# 0      99992.0          3.0       14.0  ...                       NaN
# 5       2405.0          3.0        3.0  ...                       NaN
# 9       1811.0          5.0       17.0  ...                       NaN
# 12     99981.0          4.0        7.0  ...                       NaN
# 16      5970.0          7.0        8.0  ...                       NaN
# ...        ...          ...        ...  ...                       ...
# 2716    3344.0          4.0       19.0  ...                       NaN
# 2719    3385.0          4.0       20.0  ...                       NaN
# 2724    3396.0          4.0       13.0  ...                       NaN
# 2729    3423.0          4.0       22.0  ...                       NaN
# 2734    1465.0          5.0        6.0  ...                       NaN
#
#       Participant Cause 3 Code  Participant Event 1 Code  \
# 0                          NaN                       NaN
# 5                          NaN                       NaN
# 9                          NaN                       NaN
# 12                         NaN                       NaN
# 16                         NaN                       NaN
# ...                        ...                       ...
# 2716                       NaN                       NaN
# 2719                       NaN                       NaN
# 2724                       NaN                       NaN
# 2729                       NaN                       NaN
# 2734                       NaN                       NaN
#
#       Participant Event 2 Code  Participant Event 3 Code  \
# 0                          NaN                       NaN
# 5                          NaN                       NaN
# 9                          NaN                       NaN
# 12                         NaN                       NaN
# 16                         NaN                       NaN
# ...                        ...                       ...
# 2716                       NaN                       NaN
# 2719                       NaN                       NaN
# 2724                       NaN                       NaN
# 2729                       NaN                       NaN
# 2734                       NaN                       NaN
#
#       BAC Test Results Code  Alcohol Use Reported  Drug Use Reported  \
# 0                       NaN                   NaN                NaN
# 5                       NaN                   NaN                NaN
# 9                       NaN                   NaN                NaN
# 12                      NaN                   NaN                NaN
# 16                      NaN                   NaN                NaN
# ...                     ...                   ...                ...
# 2716                    NaN                   NaN                NaN
# 2719                    NaN                   NaN                NaN
# 2724                    NaN                   NaN                NaN
# 2729                    NaN                   NaN                NaN
# 2734                    NaN                   NaN                NaN
#
#       Participant Marijuana Use Reported  Participant Striker Flag
# 0                                    NaN                       NaN
# 5                                    NaN                       NaN
# 9                                    NaN                       NaN
# 12                                   NaN                       NaN
# 16                                   NaN                       NaN
# ...                                  ...                       ...
# 2716                                 NaN                       NaN
# 2719                                 NaN                       NaN
# 2724                                 NaN                       NaN
# 2729                                 NaN                       NaN
# 2734                                 NaN                       NaN
#
# [508 rows x 157 columns]

# %%
# Assertion 1: all crashes occurred in the same year

# check the number of unique values for Crash Year
if crashes['Crash Year'].nunique() == 1:
  print("TRUE: All crashes have occurred in the same year.")
else:
  print("FALSE: Not all crashes have occurred in the same year.")
# Out:
# All crashes have occurred in the same year.

# %%
# Assertion 1: all crashes occurred on the same highway

# check the number of unique values for Highway Number
if crashes['Highway Number'].nunique() == 1:
  print("TRUE: All crashes have occurred on the same highway.")
else:
  print("FALSE: Not all crashes have occurred on the same highway.")
# Out:
# All crashes have occurred on the same highway.

# %%
# Assertion #3: the total number of vehicles involved
# is greater or equal than the number of crashes.

# count Crashes
crashes_count = crashes.shape[0]

# count the number of Vehicle entries
vehicles = df.loc[df['Record Type'] == 2]
vehicles_count = vehicles.shape[0]

if crashes_count <= vehicles_count:
  print("TRUE: The number of vehicles involved"\
        " is greater or equal than the number of crashes.")
else:
  print("FALSE: The number of vehicles involved"\
        " is less than the number of crashes.")
# Out:
# TRUE: The number of vehicles involved is greater or equal than the number of crashes.

# %%
# Assertion #3: the total number of participants involved
# is greater or equal than the number of vehicles.

# count the number of Vehicle entries
vehicles = df.loc[df['Record Type'] == 2]
vehicles_count = vehicles.shape[0]

# count the number of Participant entries
participants = df.loc[df['Record Type'] == 3]
participants_count = participants.shape[0]

if vehicles_count <= participants_count:
  print("TRUE: The number of participants involved"\
        " is greater or equal than the number of vehicles.")
else:
  print("FALSE: The number of participants involved"\
        " is less than the number of vehicles.")

print(f"Crashes: {crashes_count}")
print(f"Vehicles: {vehicles_count}")
print(f"Participants: {participants_count}")
# Out:
# TRUE: The number of participants involved is greater or equal than the number of vehicles.
# Crashes: 508
# Vehicles: 1015
# Participants: 1216

# %%
# Assertion #5: more than a half of the crashes
# have exactly two vehicles involved

# group crashes by Total Vehicle Count,
# and calculate the number of occurences for each vehicle count
counts = crashes.groupby('Total Vehicle Count').size()
counts
# Out:
# Total Vehicle Count
# 0.0    163
# 1.0    243
# 2.0     70
# 3.0     19
# 4.0     12
# 5.0      1
# dtype: int64

# %%
if counts[2] > counts.sum() / 2:
  print("TRUE: more than a half of the crashes "\
        "have exactly two vehicles involved")
else:
  print("FALSE: less than a half of the crashes "\
        "have exactly two vehicles involved")
# Out:
# FALSE: less than a half of the crasheshave exactly two vehicles involved

# %%
# Assertion #6: crashes are evenly distributed along milepoints

crashes.hist(column='Milepoint')
# Out:
# array([[<Axes: title={'center': 'Milepoint'}>]], dtype=object)

# %%
# Most crashes occur on miles 1 and 3
print("FALSE: crashes are not evenly distributed along milepoints. "\
      "Most crashes occur on miles 1 and 3.")
# Out:
# FALSE: crashes are not evenly distributed along milepoints. Most crashes occur on miles 1 and 3.
